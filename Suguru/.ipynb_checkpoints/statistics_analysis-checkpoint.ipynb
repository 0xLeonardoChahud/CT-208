# %%
import time
import signal
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import SuguruSolvers
import SASolver

# %%
SOLVERS = [SuguruSolvers.DeterministicEngine, SASolver.SASolver, SuguruSolvers.BacktrackSolver]

def timeout_handler(signum, frame):
    raise Exception('EndOfTime')

def get_instances():
    # Load instances
    instances = list()
    for root, dirs, files in os.walk('./instances'):
        for filename in files:
            file_path = os.path.join(root, filename)
            instances.append(file_path)
    return instances

def parse_suguru_binary(path):
    if not os.path.isfile(path):
        raise Exception('Error: invalid file path')

    # Load from file
    with open(path, 'rb') as fp:
        rows = int.from_bytes(fp.read(2))
        cols = int.from_bytes(fp.read(2))
        arr = np.fromfile(fp, dtype=np.int16).reshape(3, rows, cols)
    return arr

def evaluate_solved_count():
    global SOLVERS
    results = dict()
    for solver in SOLVERS:
        instances = get_instances()
        for instance in instances:
            grid, _, regions = parse_suguru_binary(instance)

            # Get puzzle statistics
            tips = np.count_nonzero(grid != 0)
            size = grid.size
            region_count = np.max(regions.flatten())
            
            # 5 Minute timeout
            signal.signal(signal.SIGALRM, timeout_handler)
            signal.alarm(300)

            # Solving using the current solver
            solved = False
            timeout = True
            try:
                s = solver(grid, regions)
                start = time.perf_counter()
                solved = s.solve()
                end = time.perf_counter()
                elapsed = end - start
            except Exception as e:
                solved = False
                timeout = True
                
            if solver not in results:
                results[solver] = {'solved':list(), 'elapsed':list(), 'puzzle':list(), 'tips':list(), 'size':list(), 'region_count':list(), 'timeout':False}
            
            if solved:
                results[solver]['solved'].append(1)
                results[solver]['elapsed'].append(elapsed)
            else:
                results[solver]['solved'].append(0)
                results[solver]['elapsed'].append(np.inf)

            results[solver]['tips'].append(tips)
            results[solver]['puzzle'].append(instance)
            results[solver]['size'].append(size)
            results[solver]['region_count'].append(region_count)
            results[solver]['timeout'] = timeout
            
            if len(results[solver]['solved']) % 100 == 0:
                print('[i] Tested: ', len(results[solver]['solved']))
            
    return results

# %%
r = evaluate_solved_count()
# Out:
# [i] Tested:  100
# [i] Tested:  200
# [i] Tested:  300
# [i] Tested:  400
# [i] Tested:  500
# [i] Tested:  600
# [i] Tested:  700
# [i] Tested:  800
# [i] Tested:  900
# [i] Tested:  1000
# [i] Tested:  1100
# [i] Tested:  1200
# [i] Tested:  1300
# [i] Tested:  1400
# [i] Tested:  1500
# [i] Tested:  1600
# [i] Tested:  1700
# [i] Tested:  100
# [i] Tested:  200
# [i] Tested:  300
# [i] Tested:  400
# [i] Tested:  500
# [i] Tested:  600
# [i] Tested:  700
# [i] Tested:  800
# [i] Tested:  900
# [i] Tested:  1000
# [i] Tested:  1100
# [i] Tested:  1200
# [i] Tested:  1300
# [i] Tested:  1400
# [i] Tested:  1500
# [i] Tested:  1600
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 r = evaluate_solved_count()
#
# Cell In[2], line 46, in evaluate_solved_count()
#      44 s = solver(grid, regions)
#      45 start = time.perf_counter()
# ---> 46 solved = s.solve()
#      47 end = time.perf_counter()
#      48 elapsed = end - start
#
# File ~/Desktop/Github/CT-208/Suguru/SASolver.py:53, in SASolver.solve(self)
#      49             self.candidates_mapping[(i,j)] = set(list(range(1, length + 1))) - set(used)
#      52 # Call to main algorithm
# ---> 53 self._simulated_annealing()
#      55 return SuguruSolvers.Checker.solved(self.grid, self.regions)
#
# File ~/Desktop/Github/CT-208/Suguru/SASolver.py:99, in SASolver._simulated_annealing(self)
#      97     resets += 1
#      98     break
# ---> 99 self._do_change(p)
#     101 new_cost = cost + self.diff_cost
#     102 delta = new_cost - cost
#
# File ~/Desktop/Github/CT-208/Suguru/SASolver.py:123, in SASolver._do_change(self, prob_shuffle)
#     121 self.changes['shuffle'] = None
#     122 self.changes['swap'] = None
# --> 123 r1 = self._get_random_invalid_region()
#     124 r2 = self._get_random_region()
#     126 if np.random.rand() < 0.1:
#
# File ~/Desktop/Github/CT-208/Suguru/SASolver.py:189, in SASolver._get_random_invalid_region(self)
#     187     tiles = self.regions_map[r]
#     188     for t in tiles:
# --> 189         if self._conflict_count(t) > 0:
#     190             return r
#     191 return None
#
# File ~/Desktop/Github/CT-208/Suguru/SASolver.py:247, in SASolver._conflict_count(self, tile)
#     245 i, j = tile
#     246 value = self.grid[i, j]
# --> 247 n_values = np.array(self._n8_values(i, j))
#     248 return np.count_nonzero(n_values == value)
#
# Cell In[2], line 4, in timeout_handler(signum, frame)
#       3 def timeout_handler(signum, frame):
# ----> 4     raise Exception('EndOfTime')
#
# Exception: EndOfTime
